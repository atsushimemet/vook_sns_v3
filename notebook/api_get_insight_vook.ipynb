# %%
import requests
import json
import datetime
from pprint import pprint
import pandas as pd
import numpy as np
import gspread

# %%
#ローカルにおいてあるconfigファイルを読み出して、認証情報を取得しておく
import sys
sys.path.append("../")
from instaapi.local_config_vook import *

# %%
version = 'v17.0'

# %%
def basic_info():
    # 初期
    config = dict()
    #アクセストークン※facebook開発アプリから取得
    config["access_token"]         = ACCESS_TOKEN
    #アプリID※facebook開発アプリから取得
    config["app_id"]               = APP_ID
    #アプリシークレット※facebook開発アプリから取得
    config["app_secret"]           = APP_SECRET
    #インスタグラムビジネスアカウントID※facebook開発アプリから取得
    config['instagram_account_id'] = INSTAGRAM_ACCOUNT_ID
    #APIバージョン
    config["version"]              = version
    # 【修正不要】graphドメイン
    config["graph_domain"]         = 'https://graph.facebook.com/'
    # 【修正不要】エンドポイント
    config["endpoint_base"]        = config["graph_domain"]+config["version"] + '/'
    # 出力
    return config

# %%
# リクエスト
params   = basic_info()       # リクエストパラメータ
#response = debugAT(params)    # レスポンス

# %%
'''各投稿のinformation(基本的な情報)を取得'''


import requests
#import pandas as pd
#pd.set_option('display.max_rows', None)

# アクセス情報
business_account_id = INSTAGRAM_ACCOUNT_ID
token = ACCESS_TOKEN
username = USER_NAME
fields = 'name,username,biography,follows_count,followers_count,media_count'
media_fields = 'timestamp,permalink,media_url,like_count,comments_count,caption'
period = 'day'


# ユーザー情報を取得する
def user_info(business_account_id=INSTAGRAM_ACCOUNT_ID,token=ACCESS_TOKEN,username=username,fields=fields):
    request_url = "https://graph.facebook.com/"+version+"/{business_account_id}?fields=business_discovery.username({username}){{{fields}}}&access_token={token}".format(business_account_id=business_account_id,username=username,fields=fields,token=token)
#     print(request_url)
    response = requests.get(request_url)
    return response.json()['business_discovery']

#print(user_info(business_account_id,token,username,fields))

# メディア情報を取得する
def user_media_info(business_account_id,token,username,media_fields):
    all_response = []

    request_url = "https://graph.facebook.com/"+version+"/{business_account_id}?fields=business_discovery.username({username}){{media{{{media_fields}}}}}&access_token={token}".format(business_account_id=business_account_id,username=username,media_fields=media_fields,token=token)
#     print(request_url)
    response = requests.get(request_url)
    result = response.json()['business_discovery']
    
    all_response.append(result['media']['data'])
    
    # 過去分がある場合は過去分全て取得する(1度に取得できる件数は25件)
    if 'after' in result['media']['paging']['cursors'].keys():
        next_token = result['media']['paging']['cursors']['after']
        while next_token is not None:
            request_url = "https://graph.facebook.com/"+version+"/{business_account_id}?fields=business_discovery.username({username}){{media.after({next_token}){{{media_fields}}}}}&access_token={token}".format(business_account_id=business_account_id,username=username,media_fields=media_fields,token=token,next_token=next_token)
#             print(request_url)
            response = requests.get(request_url)
            result = response.json()['business_discovery']
            all_response.append(result['media']['data'])
            if 'after' in result['media']['paging']['cursors'].keys():
                next_token = result['media']['paging']['cursors']['after']
            else:
                next_token = None
    
    return all_response

result = user_media_info(business_account_id,token,username,media_fields)

'''結果をデータフレームに格納'''
df_media_info = pd.DataFrame(result[0])
for noc in np.arange(1, len(result)):
    output_per_call = pd.DataFrame(result[noc])
    df_media_info = pd.concat([df_media_info,output_per_call], ignore_index=True)
    
df_media_info
# Out:
#                    timestamp                                 permalink
# 0   2023-06-17T09:02:13+0000  https://www.instagram.com/p/CtlfJBIP4pn/  \
# 1   2023-06-12T15:12:28+0000  https://www.instagram.com/p/CtZRibNPPWI/
# 2   2023-06-06T13:47:43+0000  https://www.instagram.com/p/CtJrEeVPgLv/
# 3   2023-06-04T15:45:55+0000  https://www.instagram.com/p/CtEvAaGvLe_/
# 4   2023-06-01T13:32:28+0000  https://www.instagram.com/p/Cs8xWY1viji/
# 5   2023-05-28T13:18:12+0000  https://www.instagram.com/p/CsyciYOPlq9/
# 6   2023-05-27T00:44:04+0000  https://www.instagram.com/p/CsuhcECPQ8-/
# 7   2023-05-25T13:39:34+0000  https://www.instagram.com/p/CsqwmQcPMvq/
# 8   2023-05-23T15:59:52+0000  https://www.instagram.com/p/Csl3EC1v9V3/
# 9   2023-05-16T13:50:54+0000  https://www.instagram.com/p/CsTmvWTv1z0/
# 10  2023-05-13T07:26:12+0000  https://www.instagram.com/p/CsLMVK6vbf6/
# 11  2023-05-12T01:48:21+0000  https://www.instagram.com/p/CsIA3vSvbSs/
# 12  2023-05-09T14:24:06+0000  https://www.instagram.com/p/CsBo-dxPgib/
# 13  2023-05-08T12:48:43+0000  https://www.instagram.com/p/Cr-5Q8iPpV0/
# 14  2023-05-04T14:22:04+0000  https://www.instagram.com/p/Cr0wxL7Pjay/
# 15  2023-05-03T08:49:16+0000  https://www.instagram.com/p/Crxl4z4PUkE/
# 16  2023-04-30T12:31:51+0000  https://www.instagram.com/p/CrqQ-dDvqRL/
# 17  2023-04-17T23:24:59+0000  https://www.instagram.com/p/CrJ9YuQvBmQ/
# 18  2023-04-12T14:30:51+0000  https://www.instagram.com/p/Cq8ISROv76o/
# 19  2023-04-10T03:18:13+0000  https://www.instagram.com/p/Cq1xuBGvYOd/
# 20  2023-04-07T02:38:49+0000  https://www.instagram.com/p/Cqt-0vKPhGA/
# 21  2023-04-05T14:08:15+0000  https://www.instagram.com/p/CqqEIiqvXRN/
# 22  2023-04-02T12:56:58+0000  https://www.instagram.com/p/CqiNl2mvpCH/
# 23  2023-04-01T12:57:32+0000  https://www.instagram.com/p/Cqfo3HyPDC1/
# 24  2023-03-29T13:53:57+0000  https://www.instagram.com/p/CqYA7qfvFvN/
# 25  2023-03-26T15:16:45+0000  https://www.instagram.com/p/CqQcBj4vJPd/
# 26  2023-03-24T13:32:19+0000  https://www.instagram.com/p/CqLGe6jPpjn/
# 27  2023-03-21T07:39:26+0000  https://www.instagram.com/p/CqCvto5PxP_/
# 28  2023-03-18T04:18:16+0000  https://www.instagram.com/p/Cp6qTrrPUOT/
# 29  2023-03-15T14:27:40+0000  https://www.instagram.com/p/Cp0BqXoPrhZ/
# 30  2023-03-14T14:50:02+0000  https://www.instagram.com/p/CpxfbV9PtXo/
# 31  2023-03-12T06:52:53+0000  https://www.instagram.com/p/CprfO2_vUVH/
# 32  2023-03-08T11:35:21+0000  https://www.instagram.com/p/CphsYPEv04N/
# 33  2023-03-06T13:31:39+0000  https://www.instagram.com/p/CpcwGQwyUf2/
# 34  2023-03-05T09:01:20+0000  https://www.instagram.com/p/CpZsXiKS4T0/
# 35  2023-03-04T12:31:12+0000  https://www.instagram.com/p/CpXflteS3af/
# 36  2023-03-02T14:27:42+0000  https://www.instagram.com/p/CpSjVRRyZgO/
# 37  2023-03-01T14:30:03+0000  https://www.instagram.com/p/CpP-zsAywHS/
# 38  2023-02-27T14:23:42+0000  https://www.instagram.com/p/CpK0fVgyYj3/
# 39  2023-02-26T13:29:26+0000  https://www.instagram.com/p/CpIJe_FSnBq/
# 40  2023-02-24T12:21:13+0000  https://www.instagram.com/p/CpC4Fnly9Bz/
# 41  2023-02-23T15:36:54+0000  https://www.instagram.com/p/CpApsDSS-7v/
# 42  2023-02-22T12:39:25+0000  https://www.instagram.com/p/Co9wlKUyR9-/
# 43  2023-02-21T14:35:20+0000  https://www.instagram.com/p/Co7ZDYbyF1Y/
# 44  2023-02-19T14:47:55+0000  https://www.instagram.com/p/Co2Q5r6y0Vd/
# 45  2023-02-19T12:59:22+0000  https://www.instagram.com/p/Co2EerjSU40/
# 46  2023-02-17T14:15:49+0000  https://www.instagram.com/p/CoxDo3vS6hX/
# 47  2023-02-17T10:25:57+0000  https://www.instagram.com/p/CowpVUayR_T/
# 48  2023-02-15T15:00:10+0000  https://www.instagram.com/p/Cor_H-zyddW/
# 49  2023-02-14T16:45:19+0000  https://www.instagram.com/p/CopmXRuy3tZ/
# 50  2023-02-14T16:36:13+0000  https://www.instagram.com/p/CoplUkCyDdz/
# 51  2023-02-13T14:16:34+0000  https://www.instagram.com/p/Comwi1cSyVP/
# 52  2023-02-12T03:32:31+0000  https://www.instagram.com/p/CojCC3ISlwS/
# 53  2023-02-11T12:52:47+0000  https://www.instagram.com/p/CohdXbWyq4u/
# 54  2023-02-09T14:11:10+0000  https://www.instagram.com/p/Coccv10SwEZ/
# 55  2023-02-08T14:10:48+0000  https://www.instagram.com/p/CoZ36TISoFU/
# 56  2023-02-06T16:29:41+0000  https://www.instagram.com/p/CoU-NyDS9qO/
# 57  2023-02-06T16:07:48+0000  https://www.instagram.com/p/CoU7tf3Skek/
# 58  2023-02-04T13:10:14+0000  https://www.instagram.com/p/CoPdzIhSvUl/
# 59  2023-02-03T15:34:20+0000  https://www.instagram.com/p/CoNJfsXy6go/
#
#                                             media_url  like_count
# 0   https://scontent-itm1-1.cdninstagram.com/v/t51...          25  \
# 1   https://scontent-itm1-1.cdninstagram.com/v/t51...          27
# 2   https://scontent-itm1-1.cdninstagram.com/v/t51...          46
# 3   https://scontent-itm1-1.cdninstagram.com/v/t51...          62
# 4   https://scontent-itm1-1.cdninstagram.com/v/t51...          50
# 5   https://scontent-itm1-1.cdninstagram.com/v/t51...          45
# 6   https://scontent-itm1-1.cdninstagram.com/v/t51...          38
# 7   https://scontent-itm1-1.cdninstagram.com/v/t51...          25
# 8   https://scontent-itm1-1.cdninstagram.com/v/t51...          26
# 9   https://scontent-itm1-1.cdninstagram.com/v/t51...          38
# 10  https://scontent-itm1-1.cdninstagram.com/v/t51...          50
# 11  https://scontent-itm1-1.cdninstagram.com/v/t51...          42
# 12  https://scontent-itm1-1.cdninstagram.com/v/t51...          55
# 13  https://scontent-itm1-1.cdninstagram.com/v/t51...          61
# 14  https://scontent-itm1-1.cdninstagram.com/v/t51...          34
# 15  https://scontent-itm1-1.cdninstagram.com/v/t51...          23
# 16  https://scontent-itm1-1.cdninstagram.com/v/t51...          21
# 17  https://scontent-itm1-1.cdninstagram.com/v/t51...          18
# 18  https://scontent-itm1-1.cdninstagram.com/v/t51...          27
# 19  https://scontent-itm1-1.cdninstagram.com/v/t51...          16
# 20  https://scontent-itm1-1.cdninstagram.com/v/t51...          16
# 21  https://scontent-itm1-1.cdninstagram.com/v/t51...          21
# 22  https://scontent-itm1-1.cdninstagram.com/v/t51...          16
# 23  https://scontent-itm1-1.cdninstagram.com/v/t51...          14
# 24  https://scontent-itm1-1.cdninstagram.com/v/t51...          19
# 25  https://scontent-itm1-1.cdninstagram.com/v/t51...          14
# 26  https://scontent-itm1-1.cdninstagram.com/v/t51...          17
# 27  https://scontent-itm1-1.cdninstagram.com/v/t51...          24
# 28  https://scontent-itm1-1.cdninstagram.com/v/t51...          34
# 29  https://scontent-itm1-1.cdninstagram.com/v/t51...          41
# 30  https://scontent-itm1-1.cdninstagram.com/v/t51...          24
# 31  https://scontent-itm1-1.cdninstagram.com/v/t51...          25
# 32  https://scontent-itm1-1.cdninstagram.com/v/t51...          18
# 33  https://scontent-itm1-1.cdninstagram.com/v/t51...          22
# 34  https://scontent-itm1-1.cdninstagram.com/v/t51...          34
# 35  https://scontent-itm1-1.cdninstagram.com/v/t51...          16
# 36  https://scontent-itm1-1.cdninstagram.com/v/t51...          22
# 37  https://scontent-itm1-1.cdninstagram.com/v/t51...          23
# 38  https://scontent-itm1-1.cdninstagram.com/v/t51...          17
# 39  https://scontent-itm1-1.cdninstagram.com/v/t51...          20
# 40  https://scontent-itm1-1.cdninstagram.com/v/t51...          25
# 41  https://scontent-itm1-1.cdninstagram.com/v/t51...          25
# 42  https://scontent-itm1-1.cdninstagram.com/v/t51...          20
# 43  https://scontent-itm1-1.cdninstagram.com/v/t51...          23
# 44  https://scontent-itm1-1.cdninstagram.com/v/t51...          22
# 45  https://scontent-itm1-1.cdninstagram.com/v/t51...          13
# 46  https://scontent-itm1-1.cdninstagram.com/v/t51...          12
# 47  https://scontent-itm1-1.cdninstagram.com/v/t51...          19
# 48  https://scontent-itm1-1.cdninstagram.com/v/t51...          14
# 49  https://scontent-itm1-1.cdninstagram.com/v/t51...          17
# 50  https://scontent-itm1-1.cdninstagram.com/v/t51...          98
# 51  https://scontent-itm1-1.cdninstagram.com/v/t51...          14
# 52  https://scontent-itm1-1.cdninstagram.com/v/t51...          14
# 53  https://scontent-itm1-1.cdninstagram.com/v/t51...           8
# 54  https://scontent-itm1-1.cdninstagram.com/v/t51...          19
# 55  https://scontent-itm1-1.cdninstagram.com/v/t51...           7
# 56  https://scontent-itm1-1.cdninstagram.com/v/t51...          11
# 57  https://scontent-itm1-1.cdninstagram.com/v/t51...           9
# 58  https://scontent-itm1-1.cdninstagram.com/v/t51...          12
# 59  https://scontent-itm1-1.cdninstagram.com/v/t51...          15
#
#     comments_count                                            caption
# 0                0  𝗛𝗔𝗡𝗘𝗦\n𝗙𝗥𝗨𝗜𝗧 𝗢𝗙 𝗧𝗛𝗘 𝗟𝗢𝗢𝗠\n𝗥𝗨𝗦𝗦𝗘𝗟𝗟 𝗔𝗧𝗛𝗟𝗘𝗧𝗜𝗖\n𝟭𝟵...  \
# 1                0  𝗖𝗛𝗔𝗠𝗣𝗜𝗢𝗡\n𝗧-𝗦𝗛𝗜𝗥𝗧\n𝟭𝟵𝟱𝟬𝘀〜𝟭𝟵𝟳𝟬𝘀\n年代別タグ一覧\n\n画像出...
# 2                0  𝗟𝗘𝗩𝗜'𝗦\n𝟱𝟬𝟱 𝟲𝟲前期\n\n\\解説記事//\n\n𝟬𝟭\n1973年からリリー...
# 3                1  𝗟𝗘𝗩𝗜'𝗦\n𝟱𝟬𝟱 𝗕𝗜𝗚 𝗘\n\n\\解説記事//\n\n𝟬𝟭\n1967年からリリ...
# 4                0  𝗪𝗢𝗥𝗞 𝗕𝗥𝗔𝗡𝗗\n𝟭𝟵𝟯𝟬𝙨〜𝟭𝟵𝟳𝟬𝙨\n年代別タグ一覧\n\n画像出典 \nTHR...
# 5                1  𝗨.𝗦.𝗔𝗥𝗠𝗬\n𝗢𝗚-𝟭𝟬𝟳 𝗕𝗔𝗞𝗘𝗥 𝗣𝗔𝗡𝗧𝗦\n\n\\解説記事//\n\n𝟬𝟭...
# 6                1  𝗨.𝗦.𝗔𝗥𝗠𝗬\n𝗠-𝟰𝟳 𝗕𝗔𝗞𝗘𝗥 𝗣𝗔𝗡𝗧𝗦\n\n\\解説記事//\n\n1947...
# 7                0  𝗟𝗲𝘃𝗶'𝘀 \n𝟱𝟲𝟬 𝗟𝗼𝗼𝘀𝗲 𝗙𝗶𝘁\n解説記事\n\n画像出典 \n@furugi...
# 8                1  𝗟𝗲𝘃𝗶'𝘀 \n𝟱𝟱𝟬 𝗥𝗲𝗹𝗮𝘅 𝗙𝗶𝘁\n解説記事\n\n画像出典 \n@furugi...
# 9                0  𝗛𝗘𝗔𝗗 𝗟𝗜𝗚𝗛𝗧\n𝗕𝗜𝗚 𝗬𝗔𝗡𝗞\n𝗙𝗜𝗩𝗘 𝗕𝗥𝗢𝗧𝗛𝗘𝗥 ...\n\n𝟭𝟵𝟯𝟬...
# 10               0  𝗪𝗢𝗥𝗞 𝗕𝗥𝗔𝗡𝗗\n𝟭𝟵𝟭𝟬𝘀 ~ 𝟭𝟵𝟲𝟬𝘀\n年代別タグ一覧\n\n画像出典 \nT...
# 11               0  𝗛𝗘𝗥𝗖𝗨𝗟𝗘𝗦 / 𝗕𝗜𝗚𝗠𝗔𝗖\n𝟭𝟵𝟯𝟬𝘀 ~ 𝟭𝟵𝟳𝟬𝘀\n年代別タグ一覧\n\n画...
# 12               0  𝗖𝗮𝗿𝗵𝗮𝗿𝘁𝘁 \n𝟭𝟵𝟮𝟬𝘀 ~ 𝟭𝟵𝟳𝟬𝘀\n年代別タグ一覧\n\n画像出典 \nTH...
# 13               0  𝗟𝗲𝗲\n𝟭𝟵𝟯𝟬𝘀 ~ 𝟭𝟵𝟳𝟬𝘀\n年代別タグ一覧\n\n画像出典 \nTHRIFT S...
# 14               0  購入品紹介\n-----------------------------\n“Levi's ...
# 15               0  𝗨.𝗦.𝗔𝗜𝗥 𝗙𝗢𝗥𝗖𝗘\n𝗠𝗜𝗟-𝗧-𝟰𝟯𝟯𝟱𝗔\n𝗛𝗘𝗠𝗠𝗘𝗗 𝗕𝗢𝗧𝗧𝗢𝗠𝗦\n解説...
# 16               0  𝗨.𝗦.𝗡𝗔𝗩𝗬\n𝗨𝗧𝗜𝗟𝗜𝗧𝗬 𝗣𝗔𝗡𝗧𝗦\n解説記事\n\n画像出典 \n@acorn...
# 17               0  𝗪𝗿𝗮𝗻𝗴𝗹𝗲𝗿\n𝟮𝟳𝗠𝗪\n𝗗𝗲𝗻𝗶𝗺 𝗪𝗲𝘀𝘁𝗲𝗿𝗻 𝗦𝗵𝗶𝗿𝘁\n解説記事\n\n画...
# 18               0  𝗟𝗲𝗲\n𝟵𝟭-𝗝 𝗖𝗢𝗩𝗘𝗥𝗔𝗟𝗟\n解説記事\n\n画像出典 \n@acorn_vtg ...
# 19               0  購入品紹介\n----------------------------\n\n"French...
# 20               0  𝗟𝗲𝘃𝗶'𝘀 \n𝟱𝟬𝟭 𝗕𝗟𝗔𝗖𝗞\n先染め\n解説記事\n\n画像出典 \n@feeet...
# 21               0  𝗟𝗲𝘃𝗶'𝘀 \n𝟱𝟬𝟭 𝗕𝗟𝗔𝗖𝗞\n後染め\n解説記事\n\n画像出典 \n@feeet...
# 22               0  𝗟𝗘𝗩𝗜'𝗦\n𝟲𝟬𝟲 𝗕𝗜𝗚 𝗘\n"𝗦𝗨𝗣𝗘𝗥 𝗦𝗟𝗜𝗠"\n解説記事\n\n画像出典 ...
# 23               2  𝗨.𝗦.𝗡𝗔𝗩𝗬\n𝗡-𝟯 𝗛𝗕𝗧 𝗝𝗔𝗖𝗞𝗘𝗧\n解説記事\n\n画像出典 \n@acor...
# 24               0  𝗟𝗘𝗩𝗜'𝗦\n𝟱𝟱𝟭𝗭-𝟱𝟬𝟱 ダブルネーム\n解説記事\n\n画像出典 @acorn_v...
# 25               0  購入品紹介\n----------------------------\n\nLee Wes...
# 26               0  𝗟𝗘𝗩𝗜'𝗦 \n𝟱𝟱𝟭𝗭𝗫𝗫 ギャラ無し\n解説記事\n\n画像出典 \n@acorn_v...
# 27               0  𝗟𝗘𝗩𝗜'𝗦 \n𝟱𝟱𝟭𝗭𝗫𝗫 ギャラ入り\n解説記事\n\n画像出典 \n@acorn_v...
# 28               0  𝗟𝗲𝘃𝗶'𝘀 \n𝟱𝟬𝟭 𝗥𝗘𝗗 𝗟𝗜𝗡𝗘\n赤耳\n解説記事\n\n画像出典 \n@aco...
# 29               1  𝗟𝗲𝘃𝗶'𝘀 \n𝟱𝟬𝟭 𝟲𝟲後期 \n解説記事\n\n画像出典 \n@feeet_vint...
# 30               1  𝗟𝗘𝗩𝗜'𝗦 \n𝗦𝗛𝗢𝗥𝗧 𝗛𝗢𝗥𝗡\n𝗗𝗘𝗡𝗜𝗠 𝗪𝗘𝗦𝗧𝗘𝗥𝗡 𝗦𝗛𝗜𝗥𝗧\nデニムウ...
# 31               0  購入品紹介\n----------------------------\n\nLEVI'S ...
# 32               4  𝗨.𝗦.𝗡𝗔𝗩𝗬\n𝗡-𝟭 𝗗𝗘𝗖𝗞 𝗝𝗔𝗖𝗞𝗘𝗧\nデッキジャケット\n\n解説記事\n\...
# 33               2  𝗨.𝗦.𝗔𝗥𝗠𝗬\n𝗠-𝟰𝟯 𝗛𝗕𝗧 𝗝𝗔𝗖𝗞𝗘𝗧\n解説記事\n\n画像出典 \n@fur...
# 34               0  購入品紹介\n----------------------------\n\n定期的に？購入...
# 35               2  𝗨.𝗦.𝗔𝗥𝗠𝗬\n𝗠-𝟲𝟱 𝗙𝗜𝗦𝗛𝗧𝗔𝗜𝗟 𝗣𝗔𝗥𝗞𝗔\n𝗠𝗢𝗗𝗦 𝗖𝗢𝗔𝗧\n解説記事...
# 36               1  𝗨.𝗦.𝗠𝗔𝗥𝗜𝗡𝗘 𝗖𝗢𝗥𝗣𝗦\n𝗣-𝟰𝟰 𝗛𝗕𝗧 𝗨𝗧𝗜𝗟𝗜𝗧𝗬 𝗝𝗔𝗖𝗞𝗘𝗧ユーティリ...
# 37               0  𝗨.𝗦.𝗔𝗥𝗠𝗬\n𝗠-𝟲𝟱 𝗙𝗜𝗘𝗟𝗗 𝗣𝗔𝗡𝗧𝗦\nフィールドパンツ\n解説記事\n\n...
# 38               0  𝗟𝗘𝗩𝗜'𝗦\n𝟳𝟬𝟱𝟬𝟱 𝟰𝘁𝗵 𝗕𝗜𝗚 𝗘\n解説記事\n\n画像出典 @acorn_v...
# 39               0  𝗟𝗘𝗩𝗜'𝗦\n𝟱𝟱𝟳𝗫𝗫 / 𝟱𝟱𝟳 𝟯𝗿𝗱\n解説記事\n\n画像出典 @acorn_v...
# 40               0  𝗟𝗘𝗩𝗜'𝗦 \n𝟱𝟬𝟳𝗫𝗫 𝟮𝗻𝗱\n解説記事\n\n画像出典 @acorn_vtg 様 ...
# 41               0  𝗟𝗘𝗩𝗜'𝗦 \n𝟱𝟬𝟲𝗫𝗫 𝟭𝘀𝘁\n解説記事\n\n画像出典 @beegle_by_bo...
# 42               0  𝗨.𝗦.𝗔𝗥𝗠𝗬\n𝗝𝗨𝗡𝗚𝗟𝗘 𝗙𝗔𝗧𝗜𝗚𝗨𝗘 𝗣𝗔𝗡𝗧𝗦\nジャングルファティーグパンツ...
# 43               0  𝗨.𝗦.𝗔𝗥𝗠𝗬\n𝗝𝗨𝗡𝗚𝗟𝗘 𝗙𝗔𝗧𝗜𝗚𝗨𝗘 𝗝𝗔𝗖𝗞𝗘𝗧\nジャングルファティーグジャ...
# 44               0  𝗣𝗢𝗟𝗢 𝗯𝘆 𝗥𝗮𝗹𝗽𝗵 𝗟𝗮𝘂𝗿𝗲𝗻\nモデル別 解説記事\n-- シャツ編③ --\n...
# 45               0  𝗣𝗢𝗟𝗢 𝗯𝘆 𝗥𝗮𝗹𝗽𝗵 𝗟𝗮𝘂𝗿𝗲𝗻\nモデル別 解説記事\n-- シャツ編② --\n...
# 46               0  𝗣𝗢𝗟𝗢 𝗯𝘆 𝗥𝗮𝗹𝗽𝗵 𝗟𝗮𝘂𝗿𝗲𝗻\nモデル別 解説記事\n-- シャツ編 --\n\...
# 47               0  𝗟𝗘𝗩𝗜'𝗦\n 𝟱𝟬𝟭-𝟱𝟬𝟭 ダブルネーム\n解説記事\n\n画像出典 @acorn_v...
# 48               0  𝗟𝗘𝗩𝗜'𝗦 𝟱𝟬𝟭𝗫𝗫 ギャラ無し\n解説記事\n\n画像出典 @acorn_vtg 様\...
# 49               0  𝗨.𝗦.𝗔𝗥𝗠𝗬\n𝗠-𝟲𝟱 フィールドジャケット\n\n𝟲𝟬年代〜𝟴𝟬年代の解説記事\n\...
# 50               1  𝗩𝗼𝗼𝗸\n\n [ 𝗩(𝗶𝗻𝘁𝗮𝗴𝗲) + (𝗕)𝗼𝗼𝗸 ]\n\nヴィンテージに特化した...
# 51               0  𝗟.𝗟.𝗕𝗲𝗮𝗻\n𝗕𝗢𝗔𝗧 𝗔𝗡𝗗 𝗧𝗢𝗧𝗘\n解説記事\n\n画像出典 @matin.j...
# 52               0  𝗟𝗲𝘃𝗶'𝘀 𝟱𝟬𝟭 𝟲𝟲前期 \n解説記事\n\n【古着の知識をわかりやすく公開】\n@v...
# 53               0  𝗣𝗘𝗡𝗗𝗟𝗘𝗧𝗢𝗡\n𝟯𝟬年代〜𝟵𝟬年代までの年代解説\n\n画像出典 @acorn_vtg...
# 54               0  𝗟𝗘𝗩𝗜'𝗦 𝟱𝟬𝟭𝗫𝗫 ギャラ入り\n解説記事\n\n画像出典 @feeet_vintag...
# 55               0  𝗟𝗘𝗩𝗜'𝗦 𝟱𝟬𝟭𝗫𝗫 両面タブ 革パッチ\n解説記事\n\n画像出典 @acorn_vt...
# 56               0  キング・オブ・スウェット\n𝗖𝗵𝗮𝗺𝗽𝗶𝗼𝗻 𝗥𝗘𝗩𝗘𝗥𝗦𝗘 𝗪𝗘𝗔𝗩𝗘\n𝟱𝟬年代〜𝟵𝟬年...
# 57               0  𝗟𝗘𝗩𝗜'𝗦 𝟱𝟬𝟭𝗫𝗫 片面タブ \n解説記事\n\n画像出典 @acorn_vtg 様\...
# 58               0  𝗧𝗛𝗘 ヴィンテージデニム\n𝗟𝗘𝗩𝗜'𝗦 𝟱𝟬𝟭 𝗕𝗜𝗚"𝗘" 解説\n\n【古着の知識を...
# 59               0  ヴィンテージデニムの定番\nリーバイス 𝟱𝟬𝟭 𝟲𝟲前期編\n\n【古着の知識をわかりやすく...
#
#                    id
# 0   17998169173909267
# 1   17982961961178173
# 2   18059473711410335
# 3   18181756498275594
# 4   18362833063013100
# 5   17899023626736806
# 6   17956787546605394
# 7   17954727053465183
# 8   18364412722017381
# 9   18016437298580127
# 10  17908952462766136
# 11  17913504977744291
# 12  18017560156569763
# 13  18003080209642303
# 14  18356056078041439
# 15  17953221470574981
# 16  17999832313808777
# 17  17969917193109416
# 18  17975031791189799
# 19  17854082801946830
# 20  17851239188932173
# 21  17995344505824154
# 22  17969982215081508
# 23  18012894493565855
# 24  18172618756284597
# 25  17987158117911386
# 26  17941430546610689
# 27  17910884465721374
# 28  18001355866638427
# 29  18177655660271538
# 30  17980430185896446
# 31  18178925206262147
# 32  18180448582250255
# 33  17967149993270436
# 34  18008660620575193
# 35  18321125536073779
# 36  17945715257592931
# 37  17997075967669185
# 38  17956034915435253
# 39  17957032982387600
# 40  17842846814950089
# 41  17913390308701846
# 42  17958455540212062
# 43  17886286739795566
# 44  18084595291324776
# 45  18071519197350966
# 46  17952641696309174
# 47  18015999925519855
# 48  18071148514352708
# 49  17997313759657533
# 50  17954421200432412
# 51  17845158389938795
# 52  18203253499239090
# 53  17972975654091872
# 54  17854984904878482
# 55  17959136570164359
# 56  17982401230784352
# 57  18046486810398546
# 58  17994076411676148
# 59  18038066119439034

# %%
'''ここで全投稿のmedia idのリストも作っておく'''

list_media_id = []
for noc in np.arange(len(result)):
    for nop in np.arange(len(result[noc])):
        media_id = result[noc][nop]['id']
        list_media_id.append(media_id)
print('最初の10個だけ表示：',list_media_id[:10])
print('全投稿数：',len(list_media_id))
# Out:
# 最初の10個だけ表示： ['17998169173909267', '17982961961178173', '18059473711410335', '18181756498275594', '18362833063013100', '17899023626736806', '17956787546605394', '17954727053465183', '18364412722017381', '18016437298580127']
# 全投稿数： 60

# %%
'''投稿ごとのさらに詳細なinsight(reach, saved, impressions, enagegement)を取得する
    ※これは各投稿IDごとにAPIコールが必要なため、処理に少し時間がかかる。改善方法を検討中'''

"""
    ***********************************************************************************
    【APIエンドポイント】
    https://graph.facebook.com/{graph-api-version}/{ig-media-id}/insights?metric={metric}
    ***********************************************************************************
    """
#media IDからインサイトを取得する関数
def media_insight(media_id):
    
    '''リクエスト先のurl作成'''
    metric_for_url = ''
    for mt in metric:
        metric_for_url += mt + '%2C'
    metric_for_url = metric_for_url.rstrip('%2C')
    request_url = params['endpoint_base'] + media_id + '/insights?access_token=' + params[
        'access_token'] + '&metric=' + metric_for_url
    
    response = requests.get(request_url).json()['data']
    response_reshape = dict()
    response_reshape['id'] = media_id
    response_reshape['reach'] = response[0]['values'][0]['value']
    response_reshape['impressions'] = response[1]['values'][0]['value']
    response_reshape['saved'] = response[2]['values'][0]['value']
    response_reshape['engagement'] = response[3]['values'][0]['value']
    
    return response_reshape


metric = ['reach','impressions','saved','engagement']

'''本来は以下のコードだが、一部インスタ側エラーでインサイトを取得できないのでworkaround的に対応する'''
#全てのmediaIDでインサイトを取得する
# results = []
# for nom in np.arange(len(list_media_id)):
#     media_id = list_media_id[nom]
#     out = media_insight(media_id)
#     results.append(out)
    
    
#全てのmediaIDでインサイトを取得する※workaround対応ver
results = []
for nom in np.arange(41):
    media_id = list_media_id[nom]
    out = media_insight(media_id)
    results.append(out)

# %%
df_media_insight = pd.DataFrame(results)
df_media_insight
# Out:
#                    id  reach  impressions  saved  engagement
# 0   17998169173909267    126          143      7          32
# 1   17982961961178173    149          187      7          34
# 2   18059473711410335    276          337      2          48
# 3   18181756498275594    338          421      9          72
# 4   18362833063013100    224          284      4          54
# 5   17899023626736806    322          387      3          49
# 6   17956787546605394    296          357      2          41
# 7   17954727053465183    204          251      0          25
# 8   18364412722017381    291          358      1          28
# 9   18016437298580127    254          316      6          44
# 10  17908952462766136    322          397      5          55
# 11  17913504977744291    239          306     17          59
# 12  18017560156569763    489          582     20          75
# 13  18003080209642303    291          389     22          83
# 14  18356056078041439    395          453      0          34
# 15  17953221470574981    276          321      1          24
# 16  17999832313808777    246          295      0          21
# 17  17969917193109416    210          277      1          19
# 18  17975031791189799    271          350      8          35
# 19  17854082801946830    250          315      0          16
# 20  17851239188932173    313          393      5          21
# 21  17995344505824154    330          399      7          28
# 22  17969982215081508    233          298      0          16
# 23  18012894493565855    383          464      1          17
# 24  18172618756284597    193          259      3          22
# 25  17987158117911386    247          339      0          14
# 26  17941430546610689    340          428      2          19
# 27  17910884465721374    417          509      5          29
# 28  18001355866638427    214          280      5          39
# 29  18177655660271538    277          360      5          47
# 30  17980430185896446    352          453      3          28
# 31  18178925206262147    338          443      3          28
# 32  18180448582250255    208          302      1          23
# 33  17967149993270436    386          458      1          25
# 34  18008660620575193    520          632      2          36
# 35  18321125536073779    221          268      1          19
# 36  17945715257592931    507          564      1          24
# 37  17997075967669185    270          309      3          26
# 38  17956034915435253    285          342      6          23
# 39  17957032982387600    247          309      4          24
# 40  17842846814950089    306          348      5          30

# %%
'''結合してカラムの順番整理'''

df_media = pd.merge(df_media_info,df_media_insight, how='inner', on='id')
df_media = df_media.reindex(columns=[
    'id', 'timestamp','permalink','media_url','like_count','saved','reach','impressions','engagement','caption'])
df_media
# Out:
#                    id                 timestamp
# 0   17998169173909267  2023-06-17T09:02:13+0000  \
# 1   17982961961178173  2023-06-12T15:12:28+0000
# 2   18059473711410335  2023-06-06T13:47:43+0000
# 3   18181756498275594  2023-06-04T15:45:55+0000
# 4   18362833063013100  2023-06-01T13:32:28+0000
# 5   17899023626736806  2023-05-28T13:18:12+0000
# 6   17956787546605394  2023-05-27T00:44:04+0000
# 7   17954727053465183  2023-05-25T13:39:34+0000
# 8   18364412722017381  2023-05-23T15:59:52+0000
# 9   18016437298580127  2023-05-16T13:50:54+0000
# 10  17908952462766136  2023-05-13T07:26:12+0000
# 11  17913504977744291  2023-05-12T01:48:21+0000
# 12  18017560156569763  2023-05-09T14:24:06+0000
# 13  18003080209642303  2023-05-08T12:48:43+0000
# 14  18356056078041439  2023-05-04T14:22:04+0000
# 15  17953221470574981  2023-05-03T08:49:16+0000
# 16  17999832313808777  2023-04-30T12:31:51+0000
# 17  17969917193109416  2023-04-17T23:24:59+0000
# 18  17975031791189799  2023-04-12T14:30:51+0000
# 19  17854082801946830  2023-04-10T03:18:13+0000
# 20  17851239188932173  2023-04-07T02:38:49+0000
# 21  17995344505824154  2023-04-05T14:08:15+0000
# 22  17969982215081508  2023-04-02T12:56:58+0000
# 23  18012894493565855  2023-04-01T12:57:32+0000
# 24  18172618756284597  2023-03-29T13:53:57+0000
# 25  17987158117911386  2023-03-26T15:16:45+0000
# 26  17941430546610689  2023-03-24T13:32:19+0000
# 27  17910884465721374  2023-03-21T07:39:26+0000
# 28  18001355866638427  2023-03-18T04:18:16+0000
# 29  18177655660271538  2023-03-15T14:27:40+0000
# 30  17980430185896446  2023-03-14T14:50:02+0000
# 31  18178925206262147  2023-03-12T06:52:53+0000
# 32  18180448582250255  2023-03-08T11:35:21+0000
# 33  17967149993270436  2023-03-06T13:31:39+0000
# 34  18008660620575193  2023-03-05T09:01:20+0000
# 35  18321125536073779  2023-03-04T12:31:12+0000
# 36  17945715257592931  2023-03-02T14:27:42+0000
# 37  17997075967669185  2023-03-01T14:30:03+0000
# 38  17956034915435253  2023-02-27T14:23:42+0000
# 39  17957032982387600  2023-02-26T13:29:26+0000
# 40  17842846814950089  2023-02-24T12:21:13+0000
#
#                                    permalink
# 0   https://www.instagram.com/p/CtlfJBIP4pn/  \
# 1   https://www.instagram.com/p/CtZRibNPPWI/
# 2   https://www.instagram.com/p/CtJrEeVPgLv/
# 3   https://www.instagram.com/p/CtEvAaGvLe_/
# 4   https://www.instagram.com/p/Cs8xWY1viji/
# 5   https://www.instagram.com/p/CsyciYOPlq9/
# 6   https://www.instagram.com/p/CsuhcECPQ8-/
# 7   https://www.instagram.com/p/CsqwmQcPMvq/
# 8   https://www.instagram.com/p/Csl3EC1v9V3/
# 9   https://www.instagram.com/p/CsTmvWTv1z0/
# 10  https://www.instagram.com/p/CsLMVK6vbf6/
# 11  https://www.instagram.com/p/CsIA3vSvbSs/
# 12  https://www.instagram.com/p/CsBo-dxPgib/
# 13  https://www.instagram.com/p/Cr-5Q8iPpV0/
# 14  https://www.instagram.com/p/Cr0wxL7Pjay/
# 15  https://www.instagram.com/p/Crxl4z4PUkE/
# 16  https://www.instagram.com/p/CrqQ-dDvqRL/
# 17  https://www.instagram.com/p/CrJ9YuQvBmQ/
# 18  https://www.instagram.com/p/Cq8ISROv76o/
# 19  https://www.instagram.com/p/Cq1xuBGvYOd/
# 20  https://www.instagram.com/p/Cqt-0vKPhGA/
# 21  https://www.instagram.com/p/CqqEIiqvXRN/
# 22  https://www.instagram.com/p/CqiNl2mvpCH/
# 23  https://www.instagram.com/p/Cqfo3HyPDC1/
# 24  https://www.instagram.com/p/CqYA7qfvFvN/
# 25  https://www.instagram.com/p/CqQcBj4vJPd/
# 26  https://www.instagram.com/p/CqLGe6jPpjn/
# 27  https://www.instagram.com/p/CqCvto5PxP_/
# 28  https://www.instagram.com/p/Cp6qTrrPUOT/
# 29  https://www.instagram.com/p/Cp0BqXoPrhZ/
# 30  https://www.instagram.com/p/CpxfbV9PtXo/
# 31  https://www.instagram.com/p/CprfO2_vUVH/
# 32  https://www.instagram.com/p/CphsYPEv04N/
# 33  https://www.instagram.com/p/CpcwGQwyUf2/
# 34  https://www.instagram.com/p/CpZsXiKS4T0/
# 35  https://www.instagram.com/p/CpXflteS3af/
# 36  https://www.instagram.com/p/CpSjVRRyZgO/
# 37  https://www.instagram.com/p/CpP-zsAywHS/
# 38  https://www.instagram.com/p/CpK0fVgyYj3/
# 39  https://www.instagram.com/p/CpIJe_FSnBq/
# 40  https://www.instagram.com/p/CpC4Fnly9Bz/
#
#                                             media_url  like_count  saved
# 0   https://scontent-itm1-1.cdninstagram.com/v/t51...          25      7  \
# 1   https://scontent-itm1-1.cdninstagram.com/v/t51...          27      7
# 2   https://scontent-itm1-1.cdninstagram.com/v/t51...          46      2
# 3   https://scontent-itm1-1.cdninstagram.com/v/t51...          62      9
# 4   https://scontent-itm1-1.cdninstagram.com/v/t51...          50      4
# 5   https://scontent-itm1-1.cdninstagram.com/v/t51...          45      3
# 6   https://scontent-itm1-1.cdninstagram.com/v/t51...          38      2
# 7   https://scontent-itm1-1.cdninstagram.com/v/t51...          25      0
# 8   https://scontent-itm1-1.cdninstagram.com/v/t51...          26      1
# 9   https://scontent-itm1-1.cdninstagram.com/v/t51...          38      6
# 10  https://scontent-itm1-1.cdninstagram.com/v/t51...          50      5
# 11  https://scontent-itm1-1.cdninstagram.com/v/t51...          42     17
# 12  https://scontent-itm1-1.cdninstagram.com/v/t51...          55     20
# 13  https://scontent-itm1-1.cdninstagram.com/v/t51...          61     22
# 14  https://scontent-itm1-1.cdninstagram.com/v/t51...          34      0
# 15  https://scontent-itm1-1.cdninstagram.com/v/t51...          23      1
# 16  https://scontent-itm1-1.cdninstagram.com/v/t51...          21      0
# 17  https://scontent-itm1-1.cdninstagram.com/v/t51...          18      1
# 18  https://scontent-itm1-1.cdninstagram.com/v/t51...          27      8
# 19  https://scontent-itm1-1.cdninstagram.com/v/t51...          16      0
# 20  https://scontent-itm1-1.cdninstagram.com/v/t51...          16      5
# 21  https://scontent-itm1-1.cdninstagram.com/v/t51...          21      7
# 22  https://scontent-itm1-1.cdninstagram.com/v/t51...          16      0
# 23  https://scontent-itm1-1.cdninstagram.com/v/t51...          14      1
# 24  https://scontent-itm1-1.cdninstagram.com/v/t51...          19      3
# 25  https://scontent-itm1-1.cdninstagram.com/v/t51...          14      0
# 26  https://scontent-itm1-1.cdninstagram.com/v/t51...          17      2
# 27  https://scontent-itm1-1.cdninstagram.com/v/t51...          24      5
# 28  https://scontent-itm1-1.cdninstagram.com/v/t51...          34      5
# 29  https://scontent-itm1-1.cdninstagram.com/v/t51...          41      5
# 30  https://scontent-itm1-1.cdninstagram.com/v/t51...          24      3
# 31  https://scontent-itm1-1.cdninstagram.com/v/t51...          25      3
# 32  https://scontent-itm1-1.cdninstagram.com/v/t51...          18      1
# 33  https://scontent-itm1-1.cdninstagram.com/v/t51...          22      1
# 34  https://scontent-itm1-1.cdninstagram.com/v/t51...          34      2
# 35  https://scontent-itm1-1.cdninstagram.com/v/t51...          16      1
# 36  https://scontent-itm1-1.cdninstagram.com/v/t51...          22      1
# 37  https://scontent-itm1-1.cdninstagram.com/v/t51...          23      3
# 38  https://scontent-itm1-1.cdninstagram.com/v/t51...          17      6
# 39  https://scontent-itm1-1.cdninstagram.com/v/t51...          20      4
# 40  https://scontent-itm1-1.cdninstagram.com/v/t51...          25      5
#
#     reach  impressions  engagement
# 0     126          143          32  \
# 1     149          187          34
# 2     276          337          48
# 3     338          421          72
# 4     224          284          54
# 5     322          387          49
# 6     296          357          41
# 7     204          251          25
# 8     291          358          28
# 9     254          316          44
# 10    322          397          55
# 11    239          306          59
# 12    489          582          75
# 13    291          389          83
# 14    395          453          34
# 15    276          321          24
# 16    246          295          21
# 17    210          277          19
# 18    271          350          35
# 19    250          315          16
# 20    313          393          21
# 21    330          399          28
# 22    233          298          16
# 23    383          464          17
# 24    193          259          22
# 25    247          339          14
# 26    340          428          19
# 27    417          509          29
# 28    214          280          39
# 29    277          360          47
# 30    352          453          28
# 31    338          443          28
# 32    208          302          23
# 33    386          458          25
# 34    520          632          36
# 35    221          268          19
# 36    507          564          24
# 37    270          309          26
# 38    285          342          23
# 39    247          309          24
# 40    306          348          30
#
#                                               caption
# 0   𝗛𝗔𝗡𝗘𝗦\n𝗙𝗥𝗨𝗜𝗧 𝗢𝗙 𝗧𝗛𝗘 𝗟𝗢𝗢𝗠\n𝗥𝗨𝗦𝗦𝗘𝗟𝗟 𝗔𝗧𝗛𝗟𝗘𝗧𝗜𝗖\n𝟭𝟵...
# 1   𝗖𝗛𝗔𝗠𝗣𝗜𝗢𝗡\n𝗧-𝗦𝗛𝗜𝗥𝗧\n𝟭𝟵𝟱𝟬𝘀〜𝟭𝟵𝟳𝟬𝘀\n年代別タグ一覧\n\n画像出...
# 2   𝗟𝗘𝗩𝗜'𝗦\n𝟱𝟬𝟱 𝟲𝟲前期\n\n\\解説記事//\n\n𝟬𝟭\n1973年からリリー...
# 3   𝗟𝗘𝗩𝗜'𝗦\n𝟱𝟬𝟱 𝗕𝗜𝗚 𝗘\n\n\\解説記事//\n\n𝟬𝟭\n1967年からリリ...
# 4   𝗪𝗢𝗥𝗞 𝗕𝗥𝗔𝗡𝗗\n𝟭𝟵𝟯𝟬𝙨〜𝟭𝟵𝟳𝟬𝙨\n年代別タグ一覧\n\n画像出典 \nTHR...
# 5   𝗨.𝗦.𝗔𝗥𝗠𝗬\n𝗢𝗚-𝟭𝟬𝟳 𝗕𝗔𝗞𝗘𝗥 𝗣𝗔𝗡𝗧𝗦\n\n\\解説記事//\n\n𝟬𝟭...
# 6   𝗨.𝗦.𝗔𝗥𝗠𝗬\n𝗠-𝟰𝟳 𝗕𝗔𝗞𝗘𝗥 𝗣𝗔𝗡𝗧𝗦\n\n\\解説記事//\n\n1947...
# 7   𝗟𝗲𝘃𝗶'𝘀 \n𝟱𝟲𝟬 𝗟𝗼𝗼𝘀𝗲 𝗙𝗶𝘁\n解説記事\n\n画像出典 \n@furugi...
# 8   𝗟𝗲𝘃𝗶'𝘀 \n𝟱𝟱𝟬 𝗥𝗲𝗹𝗮𝘅 𝗙𝗶𝘁\n解説記事\n\n画像出典 \n@furugi...
# 9   𝗛𝗘𝗔𝗗 𝗟𝗜𝗚𝗛𝗧\n𝗕𝗜𝗚 𝗬𝗔𝗡𝗞\n𝗙𝗜𝗩𝗘 𝗕𝗥𝗢𝗧𝗛𝗘𝗥 ...\n\n𝟭𝟵𝟯𝟬...
# 10  𝗪𝗢𝗥𝗞 𝗕𝗥𝗔𝗡𝗗\n𝟭𝟵𝟭𝟬𝘀 ~ 𝟭𝟵𝟲𝟬𝘀\n年代別タグ一覧\n\n画像出典 \nT...
# 11  𝗛𝗘𝗥𝗖𝗨𝗟𝗘𝗦 / 𝗕𝗜𝗚𝗠𝗔𝗖\n𝟭𝟵𝟯𝟬𝘀 ~ 𝟭𝟵𝟳𝟬𝘀\n年代別タグ一覧\n\n画...
# 12  𝗖𝗮𝗿𝗵𝗮𝗿𝘁𝘁 \n𝟭𝟵𝟮𝟬𝘀 ~ 𝟭𝟵𝟳𝟬𝘀\n年代別タグ一覧\n\n画像出典 \nTH...
# 13  𝗟𝗲𝗲\n𝟭𝟵𝟯𝟬𝘀 ~ 𝟭𝟵𝟳𝟬𝘀\n年代別タグ一覧\n\n画像出典 \nTHRIFT S...
# 14  購入品紹介\n-----------------------------\n“Levi's ...
# 15  𝗨.𝗦.𝗔𝗜𝗥 𝗙𝗢𝗥𝗖𝗘\n𝗠𝗜𝗟-𝗧-𝟰𝟯𝟯𝟱𝗔\n𝗛𝗘𝗠𝗠𝗘𝗗 𝗕𝗢𝗧𝗧𝗢𝗠𝗦\n解説...
# 16  𝗨.𝗦.𝗡𝗔𝗩𝗬\n𝗨𝗧𝗜𝗟𝗜𝗧𝗬 𝗣𝗔𝗡𝗧𝗦\n解説記事\n\n画像出典 \n@acorn...
# 17  𝗪𝗿𝗮𝗻𝗴𝗹𝗲𝗿\n𝟮𝟳𝗠𝗪\n𝗗𝗲𝗻𝗶𝗺 𝗪𝗲𝘀𝘁𝗲𝗿𝗻 𝗦𝗵𝗶𝗿𝘁\n解説記事\n\n画...
# 18  𝗟𝗲𝗲\n𝟵𝟭-𝗝 𝗖𝗢𝗩𝗘𝗥𝗔𝗟𝗟\n解説記事\n\n画像出典 \n@acorn_vtg ...
# 19  購入品紹介\n----------------------------\n\n"French...
# 20  𝗟𝗲𝘃𝗶'𝘀 \n𝟱𝟬𝟭 𝗕𝗟𝗔𝗖𝗞\n先染め\n解説記事\n\n画像出典 \n@feeet...
# 21  𝗟𝗲𝘃𝗶'𝘀 \n𝟱𝟬𝟭 𝗕𝗟𝗔𝗖𝗞\n後染め\n解説記事\n\n画像出典 \n@feeet...
# 22  𝗟𝗘𝗩𝗜'𝗦\n𝟲𝟬𝟲 𝗕𝗜𝗚 𝗘\n"𝗦𝗨𝗣𝗘𝗥 𝗦𝗟𝗜𝗠"\n解説記事\n\n画像出典 ...
# 23  𝗨.𝗦.𝗡𝗔𝗩𝗬\n𝗡-𝟯 𝗛𝗕𝗧 𝗝𝗔𝗖𝗞𝗘𝗧\n解説記事\n\n画像出典 \n@acor...
# 24  𝗟𝗘𝗩𝗜'𝗦\n𝟱𝟱𝟭𝗭-𝟱𝟬𝟱 ダブルネーム\n解説記事\n\n画像出典 @acorn_v...
# 25  購入品紹介\n----------------------------\n\nLee Wes...
# 26  𝗟𝗘𝗩𝗜'𝗦 \n𝟱𝟱𝟭𝗭𝗫𝗫 ギャラ無し\n解説記事\n\n画像出典 \n@acorn_v...
# 27  𝗟𝗘𝗩𝗜'𝗦 \n𝟱𝟱𝟭𝗭𝗫𝗫 ギャラ入り\n解説記事\n\n画像出典 \n@acorn_v...
# 28  𝗟𝗲𝘃𝗶'𝘀 \n𝟱𝟬𝟭 𝗥𝗘𝗗 𝗟𝗜𝗡𝗘\n赤耳\n解説記事\n\n画像出典 \n@aco...
# 29  𝗟𝗲𝘃𝗶'𝘀 \n𝟱𝟬𝟭 𝟲𝟲後期 \n解説記事\n\n画像出典 \n@feeet_vint...
# 30  𝗟𝗘𝗩𝗜'𝗦 \n𝗦𝗛𝗢𝗥𝗧 𝗛𝗢𝗥𝗡\n𝗗𝗘𝗡𝗜𝗠 𝗪𝗘𝗦𝗧𝗘𝗥𝗡 𝗦𝗛𝗜𝗥𝗧\nデニムウ...
# 31  購入品紹介\n----------------------------\n\nLEVI'S ...
# 32  𝗨.𝗦.𝗡𝗔𝗩𝗬\n𝗡-𝟭 𝗗𝗘𝗖𝗞 𝗝𝗔𝗖𝗞𝗘𝗧\nデッキジャケット\n\n解説記事\n\...
# 33  𝗨.𝗦.𝗔𝗥𝗠𝗬\n𝗠-𝟰𝟯 𝗛𝗕𝗧 𝗝𝗔𝗖𝗞𝗘𝗧\n解説記事\n\n画像出典 \n@fur...
# 34  購入品紹介\n----------------------------\n\n定期的に？購入...
# 35  𝗨.𝗦.𝗔𝗥𝗠𝗬\n𝗠-𝟲𝟱 𝗙𝗜𝗦𝗛𝗧𝗔𝗜𝗟 𝗣𝗔𝗥𝗞𝗔\n𝗠𝗢𝗗𝗦 𝗖𝗢𝗔𝗧\n解説記事...
# 36  𝗨.𝗦.𝗠𝗔𝗥𝗜𝗡𝗘 𝗖𝗢𝗥𝗣𝗦\n𝗣-𝟰𝟰 𝗛𝗕𝗧 𝗨𝗧𝗜𝗟𝗜𝗧𝗬 𝗝𝗔𝗖𝗞𝗘𝗧ユーティリ...
# 37  𝗨.𝗦.𝗔𝗥𝗠𝗬\n𝗠-𝟲𝟱 𝗙𝗜𝗘𝗟𝗗 𝗣𝗔𝗡𝗧𝗦\nフィールドパンツ\n解説記事\n\n...
# 38  𝗟𝗘𝗩𝗜'𝗦\n𝟳𝟬𝟱𝟬𝟱 𝟰𝘁𝗵 𝗕𝗜𝗚 𝗘\n解説記事\n\n画像出典 @acorn_v...
# 39  𝗟𝗘𝗩𝗜'𝗦\n𝟱𝟱𝟳𝗫𝗫 / 𝟱𝟱𝟳 𝟯𝗿𝗱\n解説記事\n\n画像出典 @acorn_v...
# 40  𝗟𝗘𝗩𝗜'𝗦 \n𝟱𝟬𝟳𝗫𝗫 𝟮𝗻𝗱\n解説記事\n\n画像出典 @acorn_vtg 様 ...

# %%
'''直近30日間のアカウントステータスを取得する'''
# ※30日は遡れる日数の上限

import datetime
#今日と28日さかのぼった日付をyyyy/mm/ddの形式で取得する 標準時に設定
delta_days = 30
today = datetime.datetime.utcnow()
date_delta = datetime.datetime.utcnow() - datetime.timedelta(days=delta_days)

yyyymmdd_td = '{yyyy}/{mm}/{dd}'.format(yyyy=today.year,mm=today.month,dd=today.day)
yyyymmdd_delta = '{yyyy}/{mm}/{dd}'.format(yyyy=date_delta.year,mm=date_delta.month,dd=date_delta.day)

print('今日の日付：',yyyymmdd_td)
print('遡った日付：',yyyymmdd_delta)
# Out:
# 今日の日付： 2023/6/18
# 遡った日付： 2023/5/19

# %%
# エンドポイントURLの作成
metric = ['follower_count','impressions','profile_views','reach']
metric_for_url = ''
for mt in metric:
    metric_for_url += mt + '%2C'
metric_for_url = metric_for_url.rstrip('%2C')

request_url = params['endpoint_base'] + params['instagram_account_id'] + '/insights?access_token=' + params[
    'access_token'] + '&metric=' + metric_for_url + '&period=day'+ '&since=' + yyyymmdd_delta + '&until=' + yyyymmdd_td
response = requests.get(request_url).json()['data']

# %%
list_endtimes = []
list_impressions = []
list_follower_count = []
list_reach = []
list_profile_views = []

for day_n in range(delta_days):
    list_endtimes.append(response[0]['values'][day_n]['end_time'])
    list_follower_count.append(response[0]['values'][day_n]['value'])
    list_impressions.append(response[1]['values'][day_n]['value'])
    list_profile_views.append(response[2]['values'][day_n]['value'])
    list_reach.append(response[3]['values'][day_n]['value'])
    
result = dict()
result['endtime'] = list_endtimes
result['follower_count'] = list_follower_count
result['profile_views'] = list_profile_views
result['impressions'] = list_impressions
result['reach'] = list_reach

# %%
#データフレームとして格納
df_account_status_in30days = pd.DataFrame(result)
df_account_status_in30days

#時系列で並び替え
df_account_status_in30days = df_account_status_in30days.sort_values(by='endtime', ascending=False, ignore_index=True)

# %%
'''google　ドライブ　スプレッドシートへの出力 ~各投稿のインサイト~'''

json_file = "../instaapi/instagram-insght-vook-dd85f5af7f10.json"
#出力先スプレッドシートの名前
work_book = "instagram_insight"
#出力先シートの名前
work_sheet = "raw"

#(gcpで設定したJsonファイルを指定)
wb = gspread.service_account(filename=json_file)
#ワークブックを選択
sh = wb.open(work_book)

# #シート一覧を取得する
# ws_list = sh.worksheets()

#シートを指定する
ws_raw1 = sh.worksheet(work_sheet)

list_column = ['id', 'timestamp','permalink','media_url','like_count','saved','reach','impressions','engagement']
#カラムを追加
ws_raw1.update('A1:I1', [list_column])
# output_df1 = pd.DataFrame(df_out[list_column]).fillna(0)
output_to_spsheet = df_media[list_column].fillna(0)

#シート変更範囲の指定
value_chenge_pos1 = 'A2:I{}'.format(len(output_to_spsheet)+1)

ws_raw1.update(value_chenge_pos1, output_to_spsheet.to_numpy().tolist())
# Out:
# {'spreadsheetId': '1mCL6IZxBKrueAj-dJIVigYFrgymw2027RieNinnpUZQ',
#  'updatedRange': 'raw!A2:I42',
#  'updatedRows': 41,
#  'updatedColumns': 9,
#  'updatedCells': 369}

# %%
'''google　ドライブ　スプレッドシートへの出力 ~直近30日のアカウントのインサイト~'''
json_file = "../instaapi/instagram-insght-vook-dd85f5af7f10.json"
#出力先スプレッドシートの名前
work_book = "instagram_insight"
#出力先シートの名前
work_sheet = "raw2"

#(gcpで設定したJsonファイルを指定)
wb = gspread.service_account(filename=json_file)
#ワークブックを選択
sh = wb.open(work_book)

# #シート一覧を取得する
# ws_list = sh.worksheets()

#シートを指定する
ws_raw2 = sh.worksheet(work_sheet)

list_column2 = ['endtime','follower_count','impressions','profile_views','reach']

#カラムを追加
ws_raw2.update('A1:E1', [list_column2])
# output_df1 = pd.DataFrame(df_out[list_column]).fillna(0)
output_to_spsheet = df_account_status_in30days[list_column2].fillna(0)

#シート変更範囲の指定
value_chenge_pos1 = 'A2:E{}'.format(len(output_to_spsheet)+1)

ws_raw2.update(value_chenge_pos1, output_to_spsheet.to_numpy().tolist())
# Out:
# {'spreadsheetId': '1mCL6IZxBKrueAj-dJIVigYFrgymw2027RieNinnpUZQ',
#  'updatedRange': "'raw2'!A2:E31",
#  'updatedRows': 30,
#  'updatedColumns': 5,
#  'updatedCells': 150}

# %%
#csvに書き出して保存
today = datetime.datetime.utcnow().strftime('%Y%m%d_%H%M%S')[:8]
df_media.to_csv('../data/output/media_insight_vook_'+today+'.csv')

# %%
#csvに書き出して保存
today = datetime.datetime.utcnow().strftime('%Y%m%d_%H%M%S')[:8]
df_account_status_in30days.to_csv('../data/output/account_status_vook_'+today+'.csv')
